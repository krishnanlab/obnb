# %%
from sys import path
path.append('../src')
from NLEval import graph, valsplit, label, model
from sklearn.metrics import roc_auc_score as auroc
import numpy as np
import pandas as pd

# %%
'''
Going to add data dir myself
Will send to Doug and Pat the data folder and they will add to it
The whole data folder will be ignored in git and github
'''

# load graph and lablset collection
data_path = '../data/' # path to data
# load graph and labelset collection
g = graph.DenseGraph.DenseGraph.from_edglst(data_path \
    + 'networks/String_experiments.edg', weighted=True, directed=False)
lsc = label.LabelsetCollection.SplitLSC.from_gmt(data_path + 'labels/c2.cp.kegg.v6.1.entrez.BP.gsea-min10-max200-ovlppt7-jacpt5.nonred.gmt')

# initialize models
SL_A = model.SupervisedLearning.LogReg(g, penalty='l2', solver='lbfgs')
# LP_A = model.LabelPropagation.LP(g)

# %%
# display label info
pd.options.display.max_rows = 999
df = pd.DataFrame()
df['Name'] = lsc.label_ids
df['Size'] = [len(lsc.get_labelset(i)) for i in lsc.label_ids]
df['Eff size'] = [len(lsc.get_labelset(i) & set(g.IDmap.lst)) for i in lsc.label_ids]
print(df)
# Out:
#                                                   Name  Size  Eff size
# 0                                      KEGG_CELL_CYCLE   128       118
# 1        KEGG_VASOPRESSIN_REGULATED_WATER_REABSORPTION    44        40
# 2                      KEGG_TGF_BETA_SIGNALING_PATHWAY    86        79
# 3                           KEGG_WNT_SIGNALING_PATHWAY   151       137
# 4                         KEGG_GLYCEROLIPID_METABOLISM    49        38
# 5                         KEGG_BETA_ALANINE_METABOLISM    22        20
# 6                          KEGG_GLUTATHIONE_METABOLISM    50        42
# 7                              KEGG_TASTE_TRANSDUCTION    52        25
# 8                                 KEGG_DNA_REPLICATION    36        34
# 9                      KEGG_CARDIAC_MUSCLE_CONTRACTION    80        66
# 10                          KEGG_RIBOFLAVIN_METABOLISM    16        12
# 11                       KEGG_ECM_RECEPTOR_INTERACTION    84        75
# 12                KEGG_DRUG_METABOLISM_CYTOCHROME_P450    72        49
# 13      KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION    44        41
# 14              KEGG_T_CELL_RECEPTOR_SIGNALING_PATHWAY   108        98
# 15                        KEGG_SPHINGOLIPID_METABOLISM    40        30
# 16                      KEGG_PENTOSE_PHOSPHATE_PATHWAY    27        24
# 17        KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS    22        20
# 18                             KEGG_RETINOL_METABOLISM    64        43
# 19                           KEGG_STEROID_BIOSYNTHESIS    17        15
# 20   KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_LACTO_AND_...    26        13
# 21                 KEGG_GLYCEROPHOSPHOLIPID_METABOLISM    77        59
# 22                          KEGG_PYRIMIDINE_METABOLISM    98        87
# 23                           KEGG_LONG_TERM_DEPRESSION    70        58
# 24                                     KEGG_PROTEASOME    48        39
# 25                KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM    34        30
# 26   KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_CHONDROITI...    22        14
# 27                                   KEGG_GAP_JUNCTION    90        82
# 28                          KEGG_N_GLYCAN_BIOSYNTHESIS    46        36
# 29                                    KEGG_ENDOCYTOSIS   183       155
# 30        KEGG_PROGESTERONE_MEDIATED_OOCYTE_MATURATION    86        80
# 31                           KEGG_HISTIDINE_METABOLISM    29        25
# 32      KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION    42        40
# 33              KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY    75        68
# 34                   KEGG_STEROID_HORMONE_BIOSYNTHESIS    55        33
# 35     KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_BIOSYNTHESIS    11         9
# 36                         KEGG_ERBB_SIGNALING_PATHWAY    87        84
# 37         KEGG_NICOTINATE_AND_NICOTINAMIDE_METABOLISM    24        19
# 38                   KEGG_DORSO_VENTRAL_AXIS_FORMATION    25        21
# 39                          KEGG_O_GLYCAN_BIOSYNTHESIS    30        19
# 40   KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_GANGLIO_SE...    15         8
# 41   KEGG_GLYCOSYLPHOSPHATIDYLINOSITOL_GPI_ANCHOR_B...    25        20
# 42                          KEGG_TRYPTOPHAN_METABOLISM    40        32
# 43                KEGG_LIMONENE_AND_PINENE_DEGRADATION    10         9
# 44              KEGG_PANTOTHENATE_AND_COA_BIOSYNTHESIS    16        12
# 45                                 KEGG_TIGHT_JUNCTION   134       111
# 46                                 KEGG_OOCYTE_MEIOSIS   114       106
# 47                    KEGG_ARACHIDONIC_ACID_METABOLISM    58        43
# 48                KEGG_FC_EPSILON_RI_SIGNALING_PATHWAY    79        69
# 49                       KEGG_PHENYLALANINE_METABOLISM    18        14
# 50                    KEGG_SELENOAMINO_ACID_METABOLISM    26        21
# 51                        KEGG_NOTCH_SIGNALING_PATHWAY    47        40
# 52                               KEGG_ABC_TRANSPORTERS    44        36
# 53                       KEGG_RENIN_ANGIOTENSIN_SYSTEM    17        16
# 54                              KEGG_PURINE_METABOLISM   159       139
# 55             KEGG_CYSTEINE_AND_METHIONINE_METABOLISM    34        29
# 56            KEGG_COMPLEMENT_AND_COAGULATION_CASCADES    69        61
# 57                      KEGG_ONE_CARBON_POOL_BY_FOLATE    17        14
# 58                        KEGG_CIRCADIAN_RHYTHM_MAMMAL    13        13
# 59                                 KEGG_PROTEIN_EXPORT    24        22
# 60                                       KEGG_LYSOSOME   121       106
# 61                    KEGG_AMINOACYL_TRNA_BIOSYNTHESIS    41        37
# 62                         KEGG_ETHER_LIPID_METABOLISM    33        23
# 63                     KEGG_HEMATOPOIETIC_CELL_LINEAGE    88        78
# 64                      KEGG_OXIDATIVE_PHOSPHORYLATION   135       115
# 65                        KEGG_REGULATION_OF_AUTOPHAGY    35        26
# 66   KEGG_INTESTINAL_IMMUNE_NETWORK_FOR_IGA_PRODUCTION    48        35
# 67                                 KEGG_RNA_POLYMERASE    29        25
# 68                           KEGG_BASE_EXCISION_REPAIR    35        33
# 69                       KEGG_LINOLEIC_ACID_METABOLISM    29        20
# 70                                KEGG_MISMATCH_REPAIR    23        22
# 71                      KEGG_INSULIN_SIGNALING_PATHWAY   137       130
# 72                    KEGG_CHEMOKINE_SIGNALING_PATHWAY   190       165
# 73                                  KEGG_MELANOGENESIS   102        94
# 74                       KEGG_HOMOLOGOUS_RECOMBINATION    28        26
# 75                          KEGG_P53_SIGNALING_PATHWAY    69        64
# 76                       KEGG_OTHER_GLYCAN_DEGRADATION    16        15
# 77               KEGG_FC_GAMMA_R_MEDIATED_PHAGOCYTOSIS    97        87
# 78                                  KEGG_AXON_GUIDANCE   129       117
# 79      KEGG_NATURAL_KILLER_CELL_MEDIATED_CYTOTOXICITY   137       103
# 80           KEGG_PORPHYRIN_AND_CHLOROPHYLL_METABOLISM    41        30
# 81                KEGG_ARGININE_AND_PROLINE_METABOLISM    54        51
# 82                          KEGG_PROPANOATE_METABOLISM    33        31
# 83                           KEGG_BUTANOATE_METABOLISM    34        28
# 84                           KEGG_GALACTOSE_METABOLISM    26        21
# 85                            KEGG_NITROGEN_METABOLISM    23        19
# 86                KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS    15        15
# 87           KEGG_LEUKOCYTE_TRANSENDOTHELIAL_MIGRATION   118        96
# 88   KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_HEPARAN_SU...    26        12
# 89        KEGG_PROXIMAL_TUBULE_BICARBONATE_RECLAMATION    23        22
# 90                         KEGG_VEGF_SIGNALING_PATHWAY    76        66
# 91                                     KEGG_PEROXISOME    78        75
# 92           KEGG_TOLL_LIKE_RECEPTOR_SIGNALING_PATHWAY   102        84
# 93                  KEGG_DRUG_METABOLISM_OTHER_ENZYMES    51        36
# 94                              KEGG_SULFUR_METABOLISM    13        10
# 95                 KEGG_PRIMARY_BILE_ACID_BIOSYNTHESIS    16        12
# 96                         KEGG_MTOR_SIGNALING_PATHWAY    52        48
# 97     KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM    32        31
# 98                         KEGG_GNRH_SIGNALING_PATHWAY   101        92
# 99                                      KEGG_APOPTOSIS    88        81
# 100                                   KEGG_SPLICEOSOME   128       114
# 101                             KEGG_ADHERENS_JUNCTION    75        68
# 102                    KEGG_NUCLEOTIDE_EXCISION_REPAIR    44        41
# 103                    KEGG_HEDGEHOG_SIGNALING_PATHWAY    56        52
# 104                     KEGG_CALCIUM_SIGNALING_PATHWAY   178       164
# 105           KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION    89        46
# 106                    KEGG_JAK_STAT_SIGNALING_PATHWAY   155       142
# 107                        KEGG_LONG_TERM_POTENTIATION    70        66
# 108                KEGG_NEUROTROPHIN_SIGNALING_PATHWAY   126       118
# 109            KEGG_TAURINE_AND_HYPOTAURINE_METABOLISM    10         8
# 110  KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_KERATAN_SU...    15         6
# 111       KEGG_GLYOXYLATE_AND_DICARBOXYLATE_METABOLISM    16        16
# 112           KEGG_NOD_LIKE_RECEPTOR_SIGNALING_PATHWAY    62        56
# 113                 KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY    56        40
# 114                           KEGG_PYRUVATE_METABOLISM    40        37
# 115                    KEGG_GLYCOLYSIS_GLUCONEOGENESIS    62        55
# 116                           KEGG_TYROSINE_METABOLISM    42        35
# 117                    KEGG_NON_HOMOLOGOUS_END_JOINING    14        12
# 118                                      KEGG_RIBOSOME    88        82
# 119   KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM    44        40
# 120                  KEGG_CELL_ADHESION_MOLECULES_CAMS   134        99
# 121                 KEGG_STARCH_AND_SUCROSE_METABOLISM    52        38
# 122         KEGG_PHOSPHATIDYLINOSITOL_SIGNALING_SYSTEM    76        65
# 123                KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS   138       129
# 124                           KEGG_FOLATE_BIOSYNTHESIS    11        11
# 125                 KEGG_GLYCOSAMINOGLYCAN_DEGRADATION    21        10
# 126         KEGG_RIG_I_LIKE_RECEPTOR_SIGNALING_PATHWAY    71        57
# 127                               KEGG_RNA_DEGRADATION    59        51
# 128                        KEGG_PPAR_SIGNALING_PATHWAY    69        63
# 129     KEGG_SNARE_INTERACTIONS_IN_VESICULAR_TRANSPORT    38        36
# 130                       KEGG_CITRATE_CYCLE_TCA_CYCLE    32        30
# 131               KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY    67        62
# 132            KEGG_VASCULAR_SMOOTH_MUSCLE_CONTRACTION   115       102
# 133      KEGG_PENTOSE_AND_GLUCURONATE_INTERCONVERSIONS    28        20
# 134   KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_GLOBO_SERIES    14         7
# 135       KEGG_GLYCINE_SERINE_AND_THREONINE_METABOLISM    31        28
# 136                         KEGG_FATTY_ACID_METABOLISM    42        40
# 137                   KEGG_BASAL_TRANSCRIPTION_FACTORS    36        30
# 138                            KEGG_LYSINE_DEGRADATION    44        40

# %%
# get labelset ID
labelID = lsc.label_ids[29]
print(labelID)
# Out:
# KEGG_ENDOCYTOSIS

# %%
# get positive and negative samples
positive_set = lsc.get_labelset(labelID)
negative_set = lsc.getNegative(labelID)
print('Positive:\n', positive_set, '\n')
print('Negative:\n', negative_set)
# Out:
# Positive:
'2205', '1892', '9826', '11238', '2938', '1290', '495', '6357', '1870', '10555', '9690', '5726', '10005', '92912', '3384', '4804', '7706', '59067', '56903', '6262', '1592', '10683', '29940', '5551', '6804', '256435', '3454', '509', '3812', '2947', '3663', '51179', '4052', '23404', '10257', '6157', '27258', '257397', '6716', '2155', '5322', '7305', '10381', '8310', '3908', '5649', '539', '8527', '2904', '6626', '920', '256471', '396', '5360', '2049', '84572', '4508', '57369', '5019', '9941', '5319', '5888', '3593', '5279', '10594', '384', '8879', '3985', '355', '10092', '26088', '84153', '90701', '50508', '64841', '8942', '262', '5604', '55276', '6870', '5434', '646821', '5908', '8625', '166336', '6234', '93', '291', '3340', '5557', '4548', '873', '3192', '1607', '642502', '117178', '3269', '4724', '230', '7066', '2812', '1452', '2531', '8985', '1718', '23395', '55432', '3084', '2113', '4124', '9341', '1312', '204', '7867', '6185', '10020', '445329', '28972', '5001', '23583', '2356', '10747', '11112', '121906', '79623', '240', '246175', '3081', '8321', '79799', '8438', '1633', '2589', '5048', '3625', '2073', '7850', '4509', '6655', '10019', '8913', '4082', '1621', '6908', '440822', '3596', '6550', '221357', '3823', '23382', '6232', '27338', '6713', '34', '245973', '64781', '2488', '11325', '9409', '224', '6591', '56603', '5970', '373156', '26227', '5305', '55454', '7855', '8654', '23530', '4047', '3123', '23521', '4670', '9978', '63917', '55811', '9343', '7416', '10312', '11194', '51129', '8702', '2629', '3597', '143187', '5739', '1943', '10509', '11224', '114', '275', '8708', '5826', '10782', '641371', '113451', '22978', '3906', '5982', '273', '387', '103', '2643', '26154', '118672', '2730', '2171', '231', '3034', '9706', '7481', '11041', '5095', '6776', '2583', '9245', '9378', '847', '2057', '3910', '390424', '5917', '144983', '51176', '5702', '7317', '6092', '3707', '6235', '514', '55670', '5321', '84265', '27306', '23193', '4790', '7384', '51164', '10533', '10235', '923', '941', '90665', '2998', '10690', '4830', '9616', '3098', '59277', '56896', '1841', '3339', '10090', '7134', '6821', '10654', '14 ...

# %%
# train and get genome wide prediction scores
model = SL_A
score_dict = model.predict(positive_set, negative_set)

# %%
# print top ranked genes and its intersection with known ones
numbers_of_top_genes = 50
top_list = sorted(score_dict, key=score_dict.get, reverse=True)[:numbers_of_top_genes]
intersection = list(set(top_list) & positive_set)
print("Top %d genes: %s" % (numbers_of_top_genes, repr(top_list)))
print("Known genes in top %d: %s" % (numbers_of_top_genes, repr(intersection)))
# Out:
# Top 50 genes: ['7334', '3190', '23291', '8655', '5241', '80143', '7184', '19', '1000', '5710', '653361', '5465', '996', '843', '5500', '8837', '2770', '85369', '2768', '8773', '6139', '9101', '5296', '6446', '5315', '701', '4478', '5695', '7171', '2697', '10454', '1161', '2690', '1540', '25759', '4967', '54512', '11235', '84313', '7381', '9474', '1514', '5694', '51606', '83443', '4216', '56915', '7327', '6124', '9739']
# Known genes in top 50: ['9101', '84313']

# %%
# user input labelset
', '11112', '121906', '79623', '240', '246175', '3081', '8321', '79799', '8438', '1633', '2589', '5048', '3625', '2073', '7850', '4509', '6655', '10019', '8913', '4082', '1621', '6908', '440822', '3596', '6550', '221357', '3823', '23382', '6232', '27338', '6713', '34', '245973', '64781', '2488', '11325', '9409', '224', '6591', '56603', '5970', '373156', '26227', '5305', '55454', '7855', '8654', '23530', '4047', '3123', '23521', '4670', '9978', '63917', '55811', '9343', '7416', '10312', '11194', '51129', '8702', '2629', '3597', '143187', '5739', '1943', '10509', '11224', '114', '275', '8708', '5826', '10782', '641371', '113451', '22978', '3906', '5982', '273', '387', '103', '2643', '26154', '118672', '2730', '2171', '231', '3034', '9706', '7481', '11041', '5095', '6776', '2583', '9245', '9378', '847', '2057', '3910', '390424', '5917', '144983', '51176', '5702', '7317', '6092', '3707', '6235', '200576', '514', '55670', '5321', '84265', '27306', '23193', '4790', '7384', '51164', '10533', '10235', '923', '161', '941', '90665', '2998', '1 ...

# %%
model = SL_A
score_dict = model.predict(lsc.get_labelset('New'), lsc.getNegative('New'))

# %%
numbers_of_top_genes = 50
top_list = sorted(score_dict, key=score_dict.get, reverse=True)[:numbers_of_top_genes]
intersection = list(set(top_list) & positive_set)
print("Top %d genes: %s" % (numbers_of_top_genes, repr(top_list)))
print("Known genes in top %d: %s" % (numbers_of_top_genes, repr(intersection)))
# Out:
# Top 50 genes: ['701', '6696', '25847', '699', '991', '9184', '246184', '29882', '119504', '29945', '8697', '2815', '3972', '10403', '4085', '996', '25936', '64682', '8881', '25906', '10393', '51433', '26271', '3973', '928', '1082', '79003', '3486', '5054', '83540', '2160', '2153', '7450', '2147', '999', '134', '51434', '3491', '2243', '3053', '2811', '2488', '58157', '7056', '93659', '835', '2244', '10287', '94115', '3827']
# Known genes in top 50: []

# %%
def example(label_index, numbers_of_top_genes, model):
    # get labelset ID
    labelID = lsc.label_ids[label_index]
    print(labelID)
    
    # get positive and negative samples
    positive_set = lsc.get_labelset(labelID)
    negative_set = lsc.getNegative(labelID)
    
    # train and get genome wide prediction scores
    score_dict = model.predict(positive_set, negative_set)
    
    # print top ranked genes and its intersection with known ones
    top_list = sorted(score_dict, key=score_dict.get, reverse=True)[:numbers_of_top_genes]
    intersection = list(set(top_list) & positive_set)
    print("Top %d genes: %s" % (numbers_of_top_genes, repr(top_list)))
    print("Known genes in top %d: %s" % (numbers_of_top_genes, repr(intersection)))

# %%
example(29, 50, SL_A)
# Out:
# KEGG_ENDOCYTOSIS
# Top 50 genes: ['7334', '3190', '23291', '8655', '5241', '80143', '7184', '19', '1000', '5710', '653361', '5465', '996', '843', '5500', '8837', '2770', '85369', '2768', '8773', '6139', '9101', '5296', '6446', '5315', '701', '4478', '5695', '7171', '2697', '10454', '1161', '2690', '1540', '25759', '4967', '54512', '11235', '84313', '7381', '9474', '1514', '5694', '51606', '83443', '4216', '56915', '7327', '6124', '9739']
# Known genes in top 50: ['9101', '84313']
