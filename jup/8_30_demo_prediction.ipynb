# %%
from sys import path
path.append('../src')
from NLEval import graph, valsplit, label, model
from sklearn.metrics import roc_auc_score as auroc
import numpy as np
import pandas as pd

# %%
# load graph and lablset collection
data_path = '../data/' # path to data
# load graph and labelset collection
g = graph.DenseGraph.DenseGraph.from_edglst(data_path \
    + 'networks/STRING-EXP.edg', weighted=True, directed=False)
lsc = label.LabelsetCollection.SplitLSC.from_gmt(data_path + 'labels/KEGGBP.gmt')

# initialize models
SL_A = model.SupervisedLearning.LogReg(g, penalty='l2', solver='lbfgs')
LP_A = model.LabelPropagation.LP(g)

# %%
# display label info
pd.options.display.max_rows = 999
df = pd.DataFrame()
df['Name'] = lsc.labelIDlst
df['Size'] = [len(lsc.getLabelset(i)) for i in lsc.labelIDlst]
df['Eff size'] = [len(lsc.getLabelset(i) & set(g.IDmap.lst)) for i in lsc.labelIDlst]
print(df)
# Out:
#                                                   Name  Size  Eff size
# 0                                      KEGG_CELL_CYCLE   128       118
# 1        KEGG_VASOPRESSIN_REGULATED_WATER_REABSORPTION    44        40
# 2                      KEGG_TGF_BETA_SIGNALING_PATHWAY    86        79
# 3                           KEGG_WNT_SIGNALING_PATHWAY   151       137
# 4                         KEGG_GLYCEROLIPID_METABOLISM    49        38
# 5                         KEGG_BETA_ALANINE_METABOLISM    22        20
# 6                          KEGG_GLUTATHIONE_METABOLISM    50        42
# 7                              KEGG_TASTE_TRANSDUCTION    52        25
# 8                                 KEGG_DNA_REPLICATION    36        34
# 9                      KEGG_CARDIAC_MUSCLE_CONTRACTION    80        66
# 10                          KEGG_RIBOFLAVIN_METABOLISM    16        12
# 11                       KEGG_ECM_RECEPTOR_INTERACTION    84        75
# 12                KEGG_DRUG_METABOLISM_CYTOCHROME_P450    72        49
# 13      KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION    44        41
# 14              KEGG_T_CELL_RECEPTOR_SIGNALING_PATHWAY   108        98
# 15                        KEGG_SPHINGOLIPID_METABOLISM    40        30
# 16                      KEGG_PENTOSE_PHOSPHATE_PATHWAY    27        24
# 17        KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS    22        20
# 18                             KEGG_RETINOL_METABOLISM    64        43
# 19                           KEGG_STEROID_BIOSYNTHESIS    17        15
# 20   KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_LACTO_AND_...    26        13
# 21                 KEGG_GLYCEROPHOSPHOLIPID_METABOLISM    77        59
# 22                          KEGG_PYRIMIDINE_METABOLISM    98        87
# 23                           KEGG_LONG_TERM_DEPRESSION    70        58
# 24                                     KEGG_PROTEASOME    48        39
# 25                KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM    34        30
# 26   KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_CHONDROITI...    22        14
# 27                                   KEGG_GAP_JUNCTION    90        82
# 28                          KEGG_N_GLYCAN_BIOSYNTHESIS    46        36
# 29                                    KEGG_ENDOCYTOSIS   183       155
# 30        KEGG_PROGESTERONE_MEDIATED_OOCYTE_MATURATION    86        80
# 31                           KEGG_HISTIDINE_METABOLISM    29        25
# 32      KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION    42        40
# 33              KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY    75        68
# 34                   KEGG_STEROID_HORMONE_BIOSYNTHESIS    55        33
# 35     KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_BIOSYNTHESIS    11         9
# 36                         KEGG_ERBB_SIGNALING_PATHWAY    87        84
# 37         KEGG_NICOTINATE_AND_NICOTINAMIDE_METABOLISM    24        19
# 38                   KEGG_DORSO_VENTRAL_AXIS_FORMATION    25        21
# 39                          KEGG_O_GLYCAN_BIOSYNTHESIS    30        19
# 40   KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_GANGLIO_SE...    15         8
# 41   KEGG_GLYCOSYLPHOSPHATIDYLINOSITOL_GPI_ANCHOR_B...    25        20
# 42                          KEGG_TRYPTOPHAN_METABOLISM    40        32
# 43                KEGG_LIMONENE_AND_PINENE_DEGRADATION    10         9
# 44              KEGG_PANTOTHENATE_AND_COA_BIOSYNTHESIS    16        12
# 45                                 KEGG_TIGHT_JUNCTION   134       111
# 46                                 KEGG_OOCYTE_MEIOSIS   114       106
# 47                    KEGG_ARACHIDONIC_ACID_METABOLISM    58        43
# 48                KEGG_FC_EPSILON_RI_SIGNALING_PATHWAY    79        69
# 49                       KEGG_PHENYLALANINE_METABOLISM    18        14
# 50                    KEGG_SELENOAMINO_ACID_METABOLISM    26        21
# 51                        KEGG_NOTCH_SIGNALING_PATHWAY    47        40
# 52                               KEGG_ABC_TRANSPORTERS    44        36
# 53                       KEGG_RENIN_ANGIOTENSIN_SYSTEM    17        16
# 54                              KEGG_PURINE_METABOLISM   159       139
# 55             KEGG_CYSTEINE_AND_METHIONINE_METABOLISM    34        29
# 56            KEGG_COMPLEMENT_AND_COAGULATION_CASCADES    69        61
# 57                      KEGG_ONE_CARBON_POOL_BY_FOLATE    17        14
# 58                        KEGG_CIRCADIAN_RHYTHM_MAMMAL    13        13
# 59                                 KEGG_PROTEIN_EXPORT    24        22
# 60                                       KEGG_LYSOSOME   121       106
# 61                    KEGG_AMINOACYL_TRNA_BIOSYNTHESIS    41        37
# 62                         KEGG_ETHER_LIPID_METABOLISM    33        23
# 63                     KEGG_HEMATOPOIETIC_CELL_LINEAGE    88        78
# 64                      KEGG_OXIDATIVE_PHOSPHORYLATION   135       115
# 65                        KEGG_REGULATION_OF_AUTOPHAGY    35        26
# 66   KEGG_INTESTINAL_IMMUNE_NETWORK_FOR_IGA_PRODUCTION    48        35
# 67                                 KEGG_RNA_POLYMERASE    29        25
# 68                           KEGG_BASE_EXCISION_REPAIR    35        33
# 69                       KEGG_LINOLEIC_ACID_METABOLISM    29        20
# 70                                KEGG_MISMATCH_REPAIR    23        22
# 71                      KEGG_INSULIN_SIGNALING_PATHWAY   137       130
# 72                    KEGG_CHEMOKINE_SIGNALING_PATHWAY   190       165
# 73                                  KEGG_MELANOGENESIS   102        94
# 74                       KEGG_HOMOLOGOUS_RECOMBINATION    28        26
# 75                          KEGG_P53_SIGNALING_PATHWAY    69        64
# 76                       KEGG_OTHER_GLYCAN_DEGRADATION    16        15
# 77               KEGG_FC_GAMMA_R_MEDIATED_PHAGOCYTOSIS    97        87
# 78                                  KEGG_AXON_GUIDANCE   129       117
# 79      KEGG_NATURAL_KILLER_CELL_MEDIATED_CYTOTOXICITY   137       103
# 80           KEGG_PORPHYRIN_AND_CHLOROPHYLL_METABOLISM    41        30
# 81                KEGG_ARGININE_AND_PROLINE_METABOLISM    54        51
# 82                          KEGG_PROPANOATE_METABOLISM    33        31
# 83                           KEGG_BUTANOATE_METABOLISM    34        28
# 84                           KEGG_GALACTOSE_METABOLISM    26        21
# 85                            KEGG_NITROGEN_METABOLISM    23        19
# 86                KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS    15        15
# 87           KEGG_LEUKOCYTE_TRANSENDOTHELIAL_MIGRATION   118        96
# 88   KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_HEPARAN_SU...    26        12
# 89        KEGG_PROXIMAL_TUBULE_BICARBONATE_RECLAMATION    23        22
# 90                         KEGG_VEGF_SIGNALING_PATHWAY    76        66
# 91                                     KEGG_PEROXISOME    78        75
# 92           KEGG_TOLL_LIKE_RECEPTOR_SIGNALING_PATHWAY   102        84
# 93                  KEGG_DRUG_METABOLISM_OTHER_ENZYMES    51        36
# 94                              KEGG_SULFUR_METABOLISM    13        10
# 95                 KEGG_PRIMARY_BILE_ACID_BIOSYNTHESIS    16        12
# 96                         KEGG_MTOR_SIGNALING_PATHWAY    52        48
# 97     KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM    32        31
# 98                         KEGG_GNRH_SIGNALING_PATHWAY   101        92
# 99                                      KEGG_APOPTOSIS    88        81
# 100                                   KEGG_SPLICEOSOME   128       114
# 101                             KEGG_ADHERENS_JUNCTION    75        68
# 102                    KEGG_NUCLEOTIDE_EXCISION_REPAIR    44        41
# 103                    KEGG_HEDGEHOG_SIGNALING_PATHWAY    56        52
# 104                     KEGG_CALCIUM_SIGNALING_PATHWAY   178       164
# 105           KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION    89        46
# 106                    KEGG_JAK_STAT_SIGNALING_PATHWAY   155       142
# 107                        KEGG_LONG_TERM_POTENTIATION    70        66
# 108                KEGG_NEUROTROPHIN_SIGNALING_PATHWAY   126       118
# 109            KEGG_TAURINE_AND_HYPOTAURINE_METABOLISM    10         8
# 110  KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_KERATAN_SU...    15         6
# 111       KEGG_GLYOXYLATE_AND_DICARBOXYLATE_METABOLISM    16        16
# 112           KEGG_NOD_LIKE_RECEPTOR_SIGNALING_PATHWAY    62        56
# 113                 KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY    56        40
# 114                           KEGG_PYRUVATE_METABOLISM    40        37
# 115                    KEGG_GLYCOLYSIS_GLUCONEOGENESIS    62        55
# 116                           KEGG_TYROSINE_METABOLISM    42        35
# 117                    KEGG_NON_HOMOLOGOUS_END_JOINING    14        12
# 118                                      KEGG_RIBOSOME    88        82
# 119   KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM    44        40
# 120                  KEGG_CELL_ADHESION_MOLECULES_CAMS   134        99
# 121                 KEGG_STARCH_AND_SUCROSE_METABOLISM    52        38
# 122         KEGG_PHOSPHATIDYLINOSITOL_SIGNALING_SYSTEM    76        65
# 123                KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS   138       129
# 124                           KEGG_FOLATE_BIOSYNTHESIS    11        11
# 125                 KEGG_GLYCOSAMINOGLYCAN_DEGRADATION    21        10
# 126         KEGG_RIG_I_LIKE_RECEPTOR_SIGNALING_PATHWAY    71        57
# 127                               KEGG_RNA_DEGRADATION    59        51
# 128                        KEGG_PPAR_SIGNALING_PATHWAY    69        63
# 129     KEGG_SNARE_INTERACTIONS_IN_VESICULAR_TRANSPORT    38        36
# 130                       KEGG_CITRATE_CYCLE_TCA_CYCLE    32        30
# 131               KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY    67        62
# 132            KEGG_VASCULAR_SMOOTH_MUSCLE_CONTRACTION   115       102
# 133      KEGG_PENTOSE_AND_GLUCURONATE_INTERCONVERSIONS    28        20
# 134   KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_GLOBO_SERIES    14         7
# 135       KEGG_GLYCINE_SERINE_AND_THREONINE_METABOLISM    31        28
# 136                         KEGG_FATTY_ACID_METABOLISM    42        40
# 137                   KEGG_BASAL_TRANSCRIPTION_FACTORS    36        30
# 138                            KEGG_LYSINE_DEGRADATION    44        40

# %%
# get labelset ID
labelID = lsc.labelIDlst[29]
print(labelID)
# Out:
# KEGG_ENDOCYTOSIS

# %%
# get positive and negative samples
positive_set = lsc.getLabelset(labelID)
negative_set = lsc.getNegative(labelID)
print('Positive:\n', positive_set, '\n')
print('Negative:\n', negative_set)
# Out:
# Positive:
#  {'1173', '2870', '2868', '22905', '3310', '11031', '2149', '116987', '23362', '10059', '11059', '10617', '157', '9525', '27243', '6011', '128866', '998', '3579', '23550', '5868', '3303', '29082', '2321', '2060', '3133', '5156', '5338', '440073', '9146', '155', '161', '22841', '3480', '30011', '57132', '84552', '3559', '9230', '7037', '30845', '1436', '80230', '8853', '51534', '409', '5979', '3312', '5337', '8411', '131890', '8766', '160', '79643', '26286', '163', '79720', '2065', '28964', '3135', '83737', '867', '7189', '1785', '9135', '26119', '55048', '9101', '3134', '4734', '10193', '1956', '23396', '1211', '7251', '2066', '51652', '9815', '1234', '154', '2261', '3265', '5869', '1212', '6457', '4914', '6455', '1759', '84249', '408', '1601', '382', '23327', '3106', '23624', '56904', '5662', '4193', '10938', '156', '7852', '26052', '3791', '23527', '27183', '84313', '3560', '200576', '29924', '64750', '89853', '23096', '3107', '93343', '1213', '11267', '80223', '1950', '3561', '6456', '51028', '10254', '868', '5590', '9744', '55040', '652614', '64744', '60682', '84440', '6714', '64411', '5867', '26056', '51510', '3815', '50807', '9829', '1175', '51100', '2869', '116985', '8394', '56288', '652799', '8396', '57154', '3577', '2264', '55616', '116984', '11311', '8395', '3105', '137492', '116986', '25978', '51160', '84364', '92421', '50855', '4233', '3304', '84612', '9922', '3306', '3949', '64145', '3305', '30844', '2263', '5878', '57403', '155382', '8218', '10015', '9727', '153', '8027', '55738', '116983', '5584', '30846'}
#
# Negative:
#  {'8643', '735', '1000', '7201', '6209', '1562', '2277', '55577', '59343', '27330', '2495', '248', '60496', '653888', '4051', '2327', '148327', '81888', '1789', '3725', '4157', '2986', '8677', '6257', '7533', '81027', '30837', '162466', '26007', '10344', '29851', '1394', '1583', '7915', '5332', '3597', '5817', '4709', '810', '9942', '2651', '51715', '521', '4696', '988', '133121', '23673', '377677', '7424', '51144', '9179', '6627', '79837', '5372', '7706', '7414', '9133', '10621', '51166', '3996', '57733', '51091', '95', '6227', '5737', '6898', '79840', '30815', '637', '6502', '7450', '6487', '196743', '553', '57369', '410', '9791', '5600', '5161', '4242', '4756', '2958', '3293', '2134', '7043', '1366', '64170', '51067', '1355', '54657', '284217', '10747', '4697', '123283', '10946', '23495', '4843', '2523', '6358', '492', '79158', '81873', '5578', '5289', '2915', '83943', '6452', '10349', '1621', '2158', '24142', '2023', '8277', '377841', '6348', '6346', '9926', '8243', '6901', '4311', '5141', '1176', '64127', '1510', '8836', '4351', '27148', '6615', '116379', '921', '1763', '1977', '23002', '27123', '1557', '239', '1437', '1339', '10672', '51135', '3636', '3163', '8555', '8898', '961', '4882', '8560', '56624', '3115', '23451', '4609', '8737', '763', '2776', '154664', '8833', '8517', '39', '6234', '701', '1636', '5371', '4694', '2921', '3803', '8454', '3075', '10056', '3357', '3552', '3451', '5238', '7409', '3643', '7412', '144165', '64768', '10477', '5500', '2120', '2072', '5933', '8818', '4638', '2814', '1603', '50835', '480', '55331', '2237', '10914', '9844', '10093', '8900', '9519', '2047', '729020', '9138', '6132', '130399', '10162', '129642', '50487', '954', '23052', '90993', '10603', '5564', '3589', '48', '3572', '2920', '482', '2710', '5048', '257194', '10993', '3444', '728', '54490', '6171', '834', '51366', '25', '166929', '85409', '7299', '64422', '8693', '823', '6206', '5827', '23643', '672', '5689', '9437', '259307', '8707', '6157', '3567', '6160', '9162', '8189', '6337', '4087', '56548', '57502', '4199', '1356', '442117', '84890', '9550', '6546', '759', '293', '6154', '1302', '8660', '925', '2017', '57505', '5565', '58477', '874', '5148', '80381', '6633', '5906', '10505', '959', '51606', '9616', '58191', '8317', '4758', '990', '6199', '107', '121278', '10540', '27030', '3913', '6375', '5328', '3381', '5024', '10892', '2966', '5260', '2788', '10509', '4323', '5298', '8399', '2946', '51196', '1293', '391013', '23553', '23171', '51111', '8554', '1593', '4837', '2762', '5336', '23192', '60495', '5624', '4668', '548596', '26301', '251', '8650', '126', '22854', '1028', '58511', '6776', '108', '9322', '11065', '314', '7534', '5607', '775', '10744', '1081', '317749', '3162', '5051', '1345', '6196', '23530', '10157', '84172', '7417', '4690', '51451', '2619', '65264', '3425', '441531', '1359', '7479', '21', '6550', '924', '51010', '397', '63826', '6667', '5319', '4540', '4719', '9899', '5159', '5021', '23705', '64506', '2909', '6385', '2891', '3029', '5230', '7364', '345645', '392255', '1452', '785', '55802', '4257', '2037', '390424', '57506', '3309', '1514', '50832', '9380', '10090', '5481', '3422', '51074', '6303', '6141', '1346', '3710', '5054', '6900', '1521', '37', '7060', '1350', '4085', '5408', '6366', '9785', '1870', '412', '23649', '3758', '875', '6147', '5588', '4712', '6165', '143686', '7059', '84938', '127', '9855', '6364', '65985', '5058', '29984', '280', '3578', '3674', '8515', '4715', '7297', '972', '54884', '10803', '4809', '2159', '476', '337876', '23062', '6648', '383', '1632', '51409', '815', '5529', '4121', '654', '23545', '891', '4086', '1677', '774', '56953', '284098', '6713', '8482', '23460', '3696', '2260', '5407', '3157', '27121', '8607', '5695', '11226', '4277', '2720', '26290', '112755', '3118', '5138', '1435', '5149', '9047', '27101', '4689', '1579', '2137', '2785', '56475', '2525', '548644', '1353', '6156', '7357', '3055', '122970', '843', '4125', '51094', '196294', '8451', '64240', '4123', '569 ...

# %%
# train and get genome wide prediction scores
model = SL_A
score_dict = model.predict(positive_set, negative_set)

# %%
# print top ranked genes and its intersection with known ones
numbers_of_top_genes = 50
top_list = sorted(score_dict, key=score_dict.get, reverse=True)[:numbers_of_top_genes]
intersection = list(set(top_list) & positive_set)
print("Top %d genes: %s" % (numbers_of_top_genes, repr(top_list)))
print("Known genes in top %d: %s" % (numbers_of_top_genes, repr(intersection)))
# Out:
# Top 50 genes: ['7533', '6714', '3725', '867', '988', '30011', '1019', '3190', '7323', '6502', '1788', '1000', '8453', '3920', '1789', '2957', '7328', '59343', '6209', '3667', '7168', '572', '4914', '7414', '6389', '1453', '7037', '637', '6627', '4175', '1871', '7706', '699', '6227', '84313', '11337', '8743', '7508', '1615', '661', '9748', '25898', '10621', '5600', '55284', '5817', '79720', '81027', '6655', '4316']
# Known genes in top 50: ['79720', '6714', '7037', '867', '4914', '84313', '30011']

# %%
# user input labelset
lsc.addLabelset(['7328', '59343', '6209', '3667', '7168', '572', '4914'], 'New')

# %%
print(lsc.getLabelset('New'))
print(lsc.getNegative('New'))
# Out:
# {'59343', '7328', '7168', '4914', '3667', '572', '6209'}
# {'2870', '8643', '735', '1000', '7201', '1562', '2277', '55577', '27330', '2495', '248', '60496', '653888', '4051', '2327', '148327', '81888', '1789', '30011', '7037', '3725', '4157', '2986', '8677', '6257', '7533', '81027', '30837', '162466', '26007', '10344', '29851', '1394', '1583', '867', '7915', '5332', '3597', '5817', '4709', '810', '9942', '2651', '51715', '521', '4696', '988', '133121', '23673', '377677', '7424', '51144', '9179', '6627', '79837', '5372', '7706', '7414', '9133', '10621', '51166', '3996', '84313', '57733', '51091', '95', '6227', '5737', '6898', '79840', '30815', '637', '6502', '7450', '6487', '196743', '553', '57369', '410', '9791', '5600', '5161', '4242', '4756', '2958', '3293', '2134', '7043', '1366', '64170', '51067', '3577', '1355', '54657', '284217', '10747', '4697', '123283', '84612', '10946', '23495', '4843', '2523', '6358', '492', '79158', '81873', '5578', '5289', '2915', '83943', '6452', '10349', '1621', '2158', '24142', '2023', '8277', '377841', '55738', '6348', '6346', '9926', '1173', '8243', '10617', '6901', '4311', '128866', '5141', '1176', '64127', '1510', '8836', '4351', '5868', '27148', '6615', '116379', '921', '1763', '1977', '23002', '27123', '1557', '239', '1437', '1339', '10672', '51135', '3636', '3163', '8555', '8898', '961', '4882', '8560', '56624', '3115', '23451', '4609', '8737', '763', '2776', '154664', '8833', '8517', '39', '6234', '701', '1636', '5371', '4694', '2921', '3803', '8454', '3075', '10056', '3357', '3552', '3451', '5238', '7409', '3643', '7412', '144165', '64768', '10477', '5500', '2120', '2072', '5933', '8818', '4638', '2814', '1603', '50835', '480', '55331', '2237', '10914', '9844', '10093', '8900', '9519', '2047', '729020', '9138', '6132', '130399', '10162', '129642', '116985', '50487', '954', '23052', '90993', '10603', '5564', '3589', '48', '3572', '2920', '482', '2710', '5048', '257194', '10993', '3444', '728', '54490', '6171', '834', '51366', '25', '10015', '166929', '85409', '7299', '64422', '8693', '823', '6206', '5827', '23643', '672', '5689', '9437', '259307', '6011', '8707', '6157', '3567', '6160', '9162', '8189', '6337', '4087', '56548', '57502', '4199', '1356', '442117', '84890', '9550', '6546', '759', '293', '6154', '1302', '8660', '925', '2017', '57505', '5565', '58477', '874', '5148', '80381', '6633', '5906', '10505', '959', '51606', '9616', '58191', '8317', '4758', '990', '6199', '107', '121278', '10540', '27030', '3913', '6375', '5328', '3381', '5024', '10892', '2966', '5260', '2788', '10509', '4323', '5298', '8399', '2946', '51196', '1293', '391013', '23553', '23171', '51111', '8554', '1593', '4837', '2762', '5336', '23192', '60495', '5624', '4668', '548596', '26301', '251', '8650', '126', '22854', '1028', '58511', '6776', '108', '9322', '11065', '314', '7534', '5607', '775', '10744', '1081', '317749', '3162', '5051', '1345', '6196', '23530', '10157', '84172', '7417', '4690', '51451', '2619', '65264', '3425', '441531', '1359', '7479', '21', '8396', '6550', '924', '51010', '397', '63826', '6667', '5319', '4540', '4719', '9899', '5159', '5021', '137492', '23705', '64506', '2909', '6385', '2891', '3029', '5230', '7364', '345645', '392255', '1452', '785', '55802', '4257', '2037', '390424', '57506', '9727', '3309', '1514', '50832', '9380', '10090', '5481', '3422', '51074', '6303', '6141', '1346', '3710', '5054', '6900', '1521', '37', '7060', '1350', '4085', '5408', '6366', '9785', '1870', '412', '23649', '3758', '875', '6147', '79643', '5588', '4712', '6165', '143686', '7059', '84938', '127', '9855', '6364', '65985', '5058', '29984', '280', '3578', '3674', '8515', '4715', '7297', '972', '54884', '10803', '2066', '4809', '2159', '476', '337876', '2261', '23062', '6648', '383', '1632', '51409', '815', '5529', '4121', '654', '23545', '891', '4086', '1677', '774', '56953', '284098', '6713', '8482', '23460', '3696', '2260', '5407', '3157', '27121', '8607', '5695', '11226', '4277', '2720', '26290', '112755', '3118', '5138', '1435', '5149', '9047', '27101', '4 ...

# %%
score_dict = model.predict(lsc.getLabelset('New'), lsc.getNegative('New'))

# %%
numbers_of_top_genes = 50
top_list = sorted(score_dict, key=score_dict.get, reverse=True)[:numbers_of_top_genes]
intersection = list(set(top_list) & positive_set)
print("Top %d genes: %s" % (numbers_of_top_genes, repr(top_list)))
print("Known genes in top %d: %s" % (numbers_of_top_genes, repr(intersection)))
# Out:
# Top 50 genes: ['8453', '1000', '2870', '22900', '29937', '2869', '735', '112464', '64399', '8454', '8065', '8643', '8451', '6923', '5727', '6921', '91653', '8452', '50937', '4522', '6569', '732', '22861', '7284', '156', '440068', '813', '10392', '9978', '1906', '10987', '55664', '733', '1448', '1003', '1908', '2767', '7428', '8533', '1013', '3091', '25828', '1447', '6532', '91662', '5663', '8450', '79139', '373509', '740']
# Known genes in top 50: ['156', '2870', '2869']

# %%
def example(label_index, numbers_of_top_genes, model):
    # get labelset ID
    labelID = lsc.labelIDlst[label_index]
    print(labelID)
    
    # get positive and negative samples
    positive_set = lsc.getLabelset(labelID)
    negative_set = lsc.getNegative(labelID)
    
    # train and get genome wide prediction scores
    score_dict = model.predict(positive_set, negative_set)
    
    # print top ranked genes and its intersection with known ones
    top_list = sorted(score_dict, key=score_dict.get, reverse=True)[:numbers_of_top_genes]
    intersection = list(set(top_list) & positive_set)
    print("Top %d genes: %s" % (numbers_of_top_genes, repr(top_list)))
    print("Known genes in top %d: %s" % (numbers_of_top_genes, repr(intersection)))

# %%
example(29, 50, SL_A)
